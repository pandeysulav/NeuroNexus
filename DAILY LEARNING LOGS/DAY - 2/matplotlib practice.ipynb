# %% [markdown]
# MATPLOTLIB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
#Simple Examples

x = np.arange(0,10)
y = np.arange(11,21)

# %%
a = np.arange(40,50)
b = np.arange(50,60)

# %%
#plotting using matplotlib


#plt scatter

plt.scatter(x,y, c='b')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Graph in 2D")
plt.savefig("Try.png")
